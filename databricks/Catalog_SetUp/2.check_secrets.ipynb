# %%
# Should return the value, not print it (Databricks masks secrets in output)
adls_key = dbutils.secrets.get(scope="migration-kv-scope", key="adls-account-key")
print("Secret retrieved:", len(adls_key) > 0)  # prints True
